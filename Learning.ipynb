# %%
import pandas as pd

# %%
data=pd.read_csv("C:\EsriTraining\DataEngineering_and_Visualization\countypres2016.csv")

# %%
data.head()
# Out:
#    year    state state_po   county    FIPS     office        candidate  \
# 0  2016  Alabama       AL  Autauga  1001.0  President  Hillary Clinton
# 1  2016  Alabama       AL  Autauga  1001.0  President     Donald Trump
# 2  2016  Alabama       AL  Autauga  1001.0  President            Other
# 3  2016  Alabama       AL  Baldwin  1003.0  President  Hillary Clinton
# 4  2016  Alabama       AL  Baldwin  1003.0  President     Donald Trump
#
#         party  candidatevotes  totalvotes   version
# 0  democratic          5936.0       24973  20190722
# 1  republican         18172.0       24973  20190722
# 2         NaN           865.0       24973  20190722
# 3  democratic         18458.0       95215  20190722
# 4  republican         72883.0       95215  20190722

# %%
data.tail()
# Out:
#       year         state state_po             county  FIPS     office  \
# 9469  2016  Rhode Island      NaN   Federal Precinct   NaN  President
# 9470  2016   Connecticut      NaN  Statewide writein   NaN  President
# 9471  2016         Maine      NaN       Maine UOCAVA   NaN  President
# 9472  2016        Alaska      NaN        District 99   NaN  President
# 9473  2016  Rhode Island      NaN   Federal Precinct   NaN  President
#
#          candidate       party  candidatevotes  totalvotes   version
# 9469  Donald Trump  republican            53.0        5056  20190722
# 9470         Other         NaN             NaN        5056  20190722
# 9471         Other         NaN           321.0        5056  20190722
# 9472         Other         NaN            28.0        5056  20190722
# 9473         Other         NaN            38.0        5056  20190722

# %%
data['totalvotes'].value_counts()
# Out:
# 5056     12
# 3225      9
# 1017      9
# 1997      9
# 7445      9
#          ..
# 31307     3
# 5776      3
# 4566      3
# 37371     3
# 48326     3
# Name: totalvotes, Length: 3012, dtype: int64

# %%
data['totalvotes'].count
# Out:
# <bound method Series.count of 0       24973
# 1       24973
# 2       24973
# 3       95215
# 4       95215
#         ...
# 9469     5056
# 9470     5056
# 9471     5056
# 9472     5056
# 9473     5056
# Name: totalvotes, Length: 9474, dtype: int64>

# %%
data['candidate'].count()
# Out:
# 9474

# %%
data[data['candidate']=='Donald Trump']
# Out:
#       year         state state_po             county     FIPS     office  \
# 1     2016       Alabama       AL            Autauga   1001.0  President
# 4     2016       Alabama       AL            Baldwin   1003.0  President
# 7     2016       Alabama       AL            Barbour   1005.0  President
# 10    2016       Alabama       AL               Bibb   1007.0  President
# 13    2016       Alabama       AL             Blount   1009.0  President
# ...    ...           ...      ...                ...      ...        ...
# 9460  2016       Wyoming       WY             Weston  56045.0  President
# 9466  2016   Connecticut      NaN  Statewide writein      NaN  President
# 9467  2016         Maine      NaN       Maine UOCAVA      NaN  President
# 9468  2016        Alaska      NaN        District 99      NaN  President
# 9469  2016  Rhode Island      NaN   Federal Precinct      NaN  President
#
#          candidate       party  candidatevotes  totalvotes   version
# ...

# %%
win['totalvotes'].sum()
# Out:
# 136535154

# %%
data['totalvotes'].sum()
# Out:
# 409605462

# %%
data[data['party']=='republican']
# Out:
#       year         state state_po             county     FIPS     office  \
# 1     2016       Alabama       AL            Autauga   1001.0  President
# 4     2016       Alabama       AL            Baldwin   1003.0  President
# 7     2016       Alabama       AL            Barbour   1005.0  President
# 10    2016       Alabama       AL               Bibb   1007.0  President
# 13    2016       Alabama       AL             Blount   1009.0  President
# ...    ...           ...      ...                ...      ...        ...
# 9460  2016       Wyoming       WY             Weston  56045.0  President
# 9466  2016   Connecticut      NaN  Statewide writein      NaN  President
# 9467  2016         Maine      NaN       Maine UOCAVA      NaN  President
# 9468  2016        Alaska      NaN        District 99      NaN  President
# 9469  2016  Rhode Island      NaN   Federal Precinct      NaN  President
#
#          candidate       party  candidatevotes  totalvotes   version
# ...

# %%
rn=data[data['state']=='Alaska']
rn
# Out:
#       year   state state_po       county    FIPS     office        candidate  \
# 201   2016  Alaska       AK   District 1  2701.0  President  Hillary Clinton
# 202   2016  Alaska       AK   District 1  2701.0  President     Donald Trump
# 203   2016  Alaska       AK   District 1  2701.0  President            Other
# 204   2016  Alaska       AK   District 2  2702.0  President  Hillary Clinton
# 205   2016  Alaska       AK   District 2  2702.0  President     Donald Trump
# ...    ...     ...      ...          ...     ...        ...              ...
# 319   2016  Alaska       AK  District 40  2740.0  President     Donald Trump
# 320   2016  Alaska       AK  District 40  2740.0  President            Other
# 9464  2016  Alaska      NaN  District 99     NaN  President  Hillary Clinton
# 9468  2016  Alaska      NaN  District 99     NaN  President     Donald Trump
# 9472  2016  Alaska      NaN  District 99     NaN  President            Other
#
# ...

# %%
nu=rn[rn['candidate']=='Donald Trump']
nu
# Out:
#       year   state state_po       county    FIPS     office     candidate  \
# 202   2016  Alaska       AK   District 1  2701.0  President  Donald Trump
# 205   2016  Alaska       AK   District 2  2702.0  President  Donald Trump
# 208   2016  Alaska       AK   District 3  2703.0  President  Donald Trump
# 211   2016  Alaska       AK   District 4  2704.0  President  Donald Trump
# 214   2016  Alaska       AK   District 5  2705.0  President  Donald Trump
# 217   2016  Alaska       AK   District 6  2706.0  President  Donald Trump
# 220   2016  Alaska       AK   District 7  2707.0  President  Donald Trump
# 223   2016  Alaska       AK   District 8  2708.0  President  Donald Trump
# 226   2016  Alaska       AK   District 9  2709.0  President  Donald Trump
# 229   2016  Alaska       AK  District 10  2710.0  President  Donald Trump
# 232   2016  Alaska       AK  District 11  2711.0  President  Donald Trump
# 235   2016  Alaska       AK  District 12  2712.0  President  Donald Trump
# ...

# %%
nu['totalvotes'].value_counts()
# Out:
# 6638     1
# 8372     1
# 9080     1
# 8127     1
# 8905     1
# 8783     1
# 11427    1
# 9394     1
# 8950     1
# 10182    1
# 7472     1
# 9934     1
# 9431     1
# 9042     1
# 8264     1
# 5062     1
# 5095     1
# 5639     1
# 4610     1
# 6924     1
# 8647     1
# 5492     1
# 7140     1
# 7613     1
# 9521     1
# 7906     1
# 8460     1
# 8294     1
# 8073     1
# 8954     1
# 9040     1
# 9689     1
# 9543     1
# 6533     1
# 10420    1
# 4982     1
# 7436     1
# 6788     1
# 7402     1
# 4792     1
# 5056     1
# Name: totalvotes, dtype: int64

# %%
nu['totalvotes'].sum()
# Out:
# 323112

# %% [markdown]
# dataset=pd.read_csv("C:\Learn\CompleteF.csv")

# %%
data['candidatevotes'].sum()
# Out:
# 136495547.0

# %%
dataset.tail()
# Out:
#       No        County Constituency                 Ward   location  latitude  \
# 551  552       Nairobi    Westlands  Parklands/Highridge  Westlands   -1.2682
# 552  553          Lamu    Lamu West                 Witu       Witu   -2.3889
# 553  554       Makueni      Makueni                 Wote       Wote   -1.7808
# 554  555  Taita Taveta     Wundanyi       Wundanyi/Mbale   Wundanyi   -3.4000
# 555  556         Siaya          Gem        Yala Township       Yala    0.0991
#
#      longitude  Total_Pred
# 551    36.8091           3
# 552    40.4382           4
# 553    37.6288           2
# 554    38.3667           2
# 555    34.5376           1

# %%
dataset.head()
# Out:
#    No      County   Constituency            Ward location  latitude  \
# 0   1      Kisumu         Nyando           Ahero    Ahero   -0.1833
# 1   2    Laikipia  Laikipia East          Sosian    Aiyam    0.3667
# 2   3  West Pokot      Kacheliba          Kiwawa    Alale    2.3333
# 3   4       Siaya   Alego Usonga          Usonga    Aldai    0.0833
# 4   5       Busia     Teso North  Malaba Central  Amagoro    0.6333
#
#    longitude  Total_Pred
# 0    34.9166           1
# 1    36.5500           3
# 2    35.0176           4
# 3    34.0667           1
# 4    34.3333           3

# %%
dataset.isnull().any
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.any of         No  County  Constituency   Ward  location  latitude  longitude  \
# 0    False   False         False  False     False     False      False
# 1    False   False         False  False     False     False      False
# 2    False   False         False  False     False     False      False
# 3    False   False         False  False     False     False      False
# 4    False   False         False  False     False     False      False
# ..     ...     ...           ...    ...       ...       ...        ...
# 551  False   False         False  False     False     False      False
# 552  False   False         False  False     False     False      False
# 553  False   False         False  False     False     False      False
# 554  False   False         False  False     False     False      False
# 555  False   False         False  False     False     False      False
#
#      Total_Pred
# 0         False
# 1         False
# ...

# %%
data.isnull()
# Out:
#        year  state  state_po  county   FIPS  office  candidate  party  \
# 0     False  False     False   False  False   False      False  False
# 1     False  False     False   False  False   False      False  False
# 2     False  False     False   False  False   False      False   True
# 3     False  False     False   False  False   False      False  False
# 4     False  False     False   False  False   False      False  False
# ...     ...    ...       ...     ...    ...     ...        ...    ...
# 9469  False  False      True   False   True   False      False  False
# 9470  False  False      True   False   True   False      False   True
# 9471  False  False      True   False   True   False      False   True
# 9472  False  False      True   False   True   False      False   True
# 9473  False  False      True   False   True   False      False   True
#
#       candidatevotes  totalvotes  version
# 0              False       False    False
# ...

# %%
#schools=pd.read_csv("C:\\Learn\\Data\\universities.csv")
schools=(r"C:\Learn\Data\universities.csv")
sh=pd.read_csv(schools)
sh.head(2)
# Out:
#              Instituition       campus     category  latitude  longitude
# 0    Africa International  main campus  private uni -1.301763  36.689659
# 1  Cooperative university  main campus   public uni -1.367400  36.728700

# %%
sh.insert(3, "students",[1000, 2000, 3000, 4000, 5000, 6000, 7000, 8000, 9000, 10000, 11000, 12000, 13000, 14000, 15000, 16000, 17000, 18000, 19000, 20000, 21000, 22000, 23000, 24000, 25000], True)
sh.head(3)
# Out:
#              Instituition          campus     category  students  latitude  \
# 0    Africa International     main campus  private uni      1000 -1.301763
# 1  Cooperative university     main campus   public uni      2000 -1.367400
# 2                 Daystar  Nairobi campus  private uni      3000 -1.301507
#
#    longitude
# 0  36.689659
# 1  36.728700
# 2  36.763770

# %%
sh.drop(['students'], axis=True).head(3)
# Out:
#              Instituition          campus     category  latitude  longitude
# 0    Africa International     main campus  private uni -1.301763  36.689659
# 1  Cooperative university     main campus   public uni -1.367400  36.728700
# 2                 Daystar  Nairobi campus  private uni -1.301507  36.763770

# %%
sh['Students']=1000, 2000, 3000, 4000, 5000, 6000, 7000, 8000, 9000, 10000, 11000, 12000, 13000, 14000, 15000, 16000, 17000, 18000, 19000, 20000, 21000, 22000, 23000, 24000, 25000
sh
# Out:
#                          Instituition                      campus  \
# 0                Africa International                 main campus
# 1              Cooperative university                 main campus
# 2                             Daystar              Nairobi campus
# 3    East Africa School of management                 city campus
# 4      East Africa School of Aviation                    Embakasi
# 5                             Egerton         Nairobi city campus
# 6              Highland state college         Nairobi CBD college
# 7         Jodan college of technology         Nairobi city campus
# 8                               JKUAT          Nairobi CBD centre
# 9                               JKUAT                Karen campus
# 10                              JKUAT             Westland campus
# 11                 Kabarak university         Nairobi city campus
# 12                                KCA                  CBD campus
# ...

# %%
sh.drop(['students'], axis=True)
# Out:
#                          Instituition                      campus  \
# 0                Africa International                 main campus
# 1              Cooperative university                 main campus
# 2                             Daystar              Nairobi campus
# 3    East Africa School of management                 city campus
# 4      East Africa School of Aviation                    Embakasi
# 5                             Egerton         Nairobi city campus
# 6              Highland state college         Nairobi CBD college
# 7         Jodan college of technology         Nairobi city campus
# 8                               JKUAT          Nairobi CBD centre
# 9                               JKUAT                Karen campus
# 10                              JKUAT             Westland campus
# 11                 Kabarak university         Nairobi city campus
# 12                                KCA                  CBD campus
# ...

# %%
we=sh.drop(['Students'], axis=True)
we
# Out:
#                          Instituition                      campus  \
# 0                Africa International                 main campus
# 1              Cooperative university                 main campus
# 2                             Daystar              Nairobi campus
# 3    East Africa School of management                 city campus
# 4      East Africa School of Aviation                    Embakasi
# 5                             Egerton         Nairobi city campus
# 6              Highland state college         Nairobi CBD college
# 7         Jodan college of technology         Nairobi city campus
# 8                               JKUAT          Nairobi CBD centre
# 9                               JKUAT                Karen campus
# 10                              JKUAT             Westland campus
# 11                 Kabarak university         Nairobi city campus
# 12                                KCA                  CBD campus
# ...

# %%
we.drop(['students'], axis=True)
# Out:
#                          Instituition                      campus  \
# 0                Africa International                 main campus
# 1              Cooperative university                 main campus
# 2                             Daystar              Nairobi campus
# 3    East Africa School of management                 city campus
# 4      East Africa School of Aviation                    Embakasi
# 5                             Egerton         Nairobi city campus
# 6              Highland state college         Nairobi CBD college
# 7         Jodan college of technology         Nairobi city campus
# 8                               JKUAT          Nairobi CBD centre
# 9                               JKUAT                Karen campus
# 10                              JKUAT             Westland campus
# 11                 Kabarak university         Nairobi city campus
# 12                                KCA                  CBD campus
# ...

# %%
sh[sh['campus']=='main campus']
# Out:
#                          Instituition       campus     category  latitude  \
# 0                Africa International  main campus  private uni -1.301763
# 1              Cooperative university  main campus   public uni -1.367400
# 16   Kenya Scholl of Monetary stuties  main campus         TVET -1.249980
# 20                   Kenya university  main campus   public uni -1.180568
# 21              University of Nairobi  main campus   public uni -1.280423
# 22  The technical University of Kenya  main campus   public uni -1.291140
#
#     longitude  Students
# 0   36.689659      1000
# 1   36.728700      2000
# 16  36.865850     17000
# 20  36.928042     21000
# 21  36.816311     22000
# 22  36.824020     23000

# %%
df=pd.read_csv("C:\Learn\Data\Register.csv")

# %%
df.head()
# Out:
#       Name  Reg_No Institution
# 0      Dan    2343       KISII
# 1  Vincent    7688         TUK
# 2   Wesley    4533       RVIST
# 3       JP    2344       RVTTI
# 4    Faith    2455         UOE

# %%
df['Parent']="James", "Dorcas", "Thomas", "Grace", "William", "Jacquiline", "John", "Hosea", "Samwel", "Andrew"
df
# Out:
#       Name  Reg_No Institution      Parent
# 0      Dan    2343       KISII       James
# 1  Vincent    7688         TUK      Dorcas
# 2   Wesley    4533       RVIST      Thomas
# 3       JP    2344       RVTTI       Grace
# 4    Faith    2455         UOE     William
# 5     Joan    3477    KABIANGA  Jacquiline
# 6    Joash    4366     KABARAK        John
# 7  Justine    3243       JKUAT       Hosea
# 8      Roy    2300         UON      Samwel
# 9    Enock    2200          KU      Andrew

# %%
df['Phone_Number']= 765789099, 73376855, 789765877, 745676564, 743676897, 786879765, 78986549, 734543675, 723456654, 765765432
df
# Out:
#       Name  Reg_No Institution      Parent  Phone_Number
# 0      Dan    2343       KISII       James     765789099
# 1  Vincent    7688         TUK      Dorcas      73376855
# 2   Wesley    4533       RVIST      Thomas     789765877
# 3       JP    2344       RVTTI       Grace     745676564
# 4    Faith    2455         UOE     William     743676897
# 5     Joan    3477    KABIANGA  Jacquiline     786879765
# 6    Joash    4366     KABARAK        John      78986549
# 7  Justine    3243       JKUAT       Hosea     734543675
# 8      Roy    2300         UON      Samwel     723456654
# 9    Enock    2200          KU      Andrew     765765432
