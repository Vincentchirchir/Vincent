# %%
pip install seaborn
# Out:
# Collecting seaborn
#   Using cached seaborn-0.12.2-py3-none-any.whl (293 kB)
# Requirement already satisfied: pandas>=0.25 in c:\users\vincent kipruto\anaconda3\envs\gis-enviro\lib\site-packages (from seaborn) (1.5.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.17 in c:\users\vincent kipruto\anaconda3\envs\gis-enviro\lib\site-packages (from seaborn) (1.23.5)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.1 in c:\users\vincent kipruto\anaconda3\envs\gis-enviro\lib\site-packages (from seaborn) (3.6.2)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\vincent kipruto\anaconda3\envs\gis-enviro\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (4.25.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\vincent kipruto\anaconda3\envs\gis-enviro\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (1.0.5)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\vincent kipruto\anaconda3\envs\gis-enviro\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (2.8.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\vincent kipruto\anaconda3\envs\gis-enviro\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (0.11.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\vincent kipruto\anaconda3\envs\gis-enviro\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (22.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\vincent kipruto\anaconda3\envs\gis-enviro\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (1.4.4)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\vincent kipruto\anaconda3\envs\gis-enviro\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (9.1.0)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\vincent kipruto\anaconda3\envs\gis-enviro\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (3.0.9)
# Requirement already satisfied: pytz>=2020.1 in c:\users\vincent kipruto\anaconda3\envs\gis-enviro\lib\site-packages\pytz-2022.6-py3.9.egg (from pandas>=0.25->seaborn) (2022.6)
# Requirement already satisfied: six>=1.5 in c:\users\vincent kipruto\anaconda3\envs\gis-enviro\lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.1->seaborn) (1.16.0)
# Installing collected packages: seaborn
# Successfully installed seaborn-0.12.2
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import seaborn as sns

# %%
data0=pd.read_csv("C:/Users/VINCENT KIPRUTO/Documents/Final Year Project😎/Data/wfp_food_prices_kenya.csv")

# %% [markdown]
# # Data Cleaning

# %%
data=data0[data0['priceflag']=='actual']
data
# Out:
#             date       admin1      admin2                 market   latitude  \
# 1      1/15/2006        Coast     Mombasa                Mombasa      -4.05
# 2      1/15/2006        Coast     Mombasa                Mombasa      -4.05
# 3      1/15/2006        Coast     Mombasa                Mombasa      -4.05
# 4      1/15/2006        Coast     Mombasa                Mombasa      -4.05
# 5      1/15/2006      Eastern       Kitui                  Kitui  -1.366667
# ...          ...          ...         ...                    ...        ...
# 9975  10/15/2022  Rift Valley  West Pokot  Makutano (West Pokot)   1.253093
# 9976  10/15/2022  Rift Valley  West Pokot  Makutano (West Pokot)   1.253093
# 9977  10/15/2022  Rift Valley  West Pokot  Makutano (West Pokot)   1.253093
# 9978  10/15/2022  Rift Valley  West Pokot  Makutano (West Pokot)   1.253093
# 9979  10/15/2022  Rift Valley  West Pokot  Makutano (West Pokot)   1.253093
#
#       longitude               category         commodity    unit priceflag  \
# 1     39.666667     cereals and tubers             Maize      KG    actual
# 2     39.666667     cereals and tubers     Maize (white)   90 KG    actual
# 3     39.666667        pulses and nuts             Beans      KG    actual
# 4     39.666667        pulses and nuts       Beans (dry)   90 KG    actual
# 5     38.016667     cereals and tubers     Maize (white)      KG    actual
# ...         ...                    ...               ...     ...       ...
# 9975  35.076653        pulses and nuts  Beans (rosecoco)   90 KG    actual
# 9976  35.076653  vegetables and fruits           Cabbage  126 KG    actual
# 9977  35.076653  vegetables and fruits              Kale   50 KG    actual
# 9978  35.076653  vegetables and fruits      Onions (dry)   13 KG    actual
# 9979  35.076653  vegetables and fruits          Tomatoes   64 KG    actual
#
#       pricetype currency    price usdprice
# 1     Wholesale      KES    16.13   0.2235
# 2     Wholesale      KES     1480  20.5041
# 3     Wholesale      KES    33.63   0.4659
# 4     Wholesale      KES     3246  44.9705
# 5        Retail      KES       17   0.2355
# ...         ...      ...      ...      ...
# 9975  Wholesale      KES     9432  79.3939
# 9976  Wholesale      KES  2007.18  16.8955
# 9977  Wholesale      KES     1385  11.6582
# 9978  Wholesale      KES    643.5   5.4167
# 9979  Wholesale      KES     2640  22.2222
#
# [9979 rows x 14 columns]

# %%
data.shape
# Out:
# (9979, 14)

# %%
data.isnull().sum()
# Out:
# date         0
# admin1       0
# admin2       0
# market       0
# latitude     0
# longitude    0
# category     0
# commodity    0
# unit         0
# priceflag    0
# pricetype    0
# currency     0
# price        0
# usdprice     0
# dtype: int64

# %%
data.duplicated().sum()
# Out:
# 0

# %%
data.head()
# Out:
#         date   admin1   admin2   market   latitude  longitude  \
# 1  1/15/2006    Coast  Mombasa  Mombasa      -4.05  39.666667
# 2  1/15/2006    Coast  Mombasa  Mombasa      -4.05  39.666667
# 3  1/15/2006    Coast  Mombasa  Mombasa      -4.05  39.666667
# 4  1/15/2006    Coast  Mombasa  Mombasa      -4.05  39.666667
# 5  1/15/2006  Eastern    Kitui    Kitui  -1.366667  38.016667
#
#              category      commodity   unit priceflag  pricetype currency  \
# 1  cereals and tubers          Maize     KG    actual  Wholesale      KES
# 2  cereals and tubers  Maize (white)  90 KG    actual  Wholesale      KES
# 3     pulses and nuts          Beans     KG    actual  Wholesale      KES
# 4     pulses and nuts    Beans (dry)  90 KG    actual  Wholesale      KES
# 5  cereals and tubers  Maize (white)     KG    actual     Retail      KES
#
#    price usdprice
# 1  16.13   0.2235
# 2   1480  20.5041
# 3  33.63   0.4659
# 4   3246  44.9705
# 5     17   0.2355

# %%
maize=data[data['commodity']=='Maize']
maize
# Out:
#            date       admin1       admin2                      market  \
# 1     1/15/2006        Coast      Mombasa                     Mombasa
# 11    1/15/2006      Nairobi      Nairobi                     Nairobi
# 20    1/15/2006       Nyanza       Kisumu                      Kisumu
# 27    1/15/2006  Rift Valley  Uasin Gishu  Eldoret town (Uasin Gishu)
# 31    2/15/2006        Coast      Mombasa                     Mombasa
# ...         ...          ...          ...                         ...
# 9014  3/15/2022      Nairobi      Nairobi                     Nairobi
# 9051  3/15/2022  Rift Valley       Nakuru                      Nakuru
# 9064  3/15/2022  Rift Valley  Uasin Gishu  Eldoret town (Uasin Gishu)
# 9160  4/15/2022  Rift Valley       Nakuru                      Nakuru
# 9171  4/15/2022  Rift Valley  Uasin Gishu  Eldoret town (Uasin Gishu)
#
#        latitude  longitude            category commodity unit priceflag  \
# 1         -4.05  39.666667  cereals and tubers     Maize   KG    actual
# 11    -1.283333  36.816667  cereals and tubers     Maize   KG    actual
# 20         -0.1      34.75  cereals and tubers     Maize   KG    actual
# 27     0.516667  35.283333  cereals and tubers     Maize   KG    actual
# 31        -4.05  39.666667  cereals and tubers     Maize   KG    actual
# ...         ...        ...                 ...       ...  ...       ...
# 9014  -1.283333  36.816667  cereals and tubers     Maize   KG    actual
# 9051   -0.28296    36.0744  cereals and tubers     Maize   KG    actual
# 9064   0.516667  35.283333  cereals and tubers     Maize   KG    actual
# 9160   -0.28296    36.0744  cereals and tubers     Maize   KG    actual
# 9171   0.516667  35.283333  cereals and tubers     Maize   KG    actual
#
#       pricetype currency  price usdprice
# 1     Wholesale      KES  16.13   0.2235
# 11    Wholesale      KES  15.48   0.2145
# 20    Wholesale      KES  14.84   0.2055
# 27    Wholesale      KES  12.96   0.1796
# 31    Wholesale      KES  16.41   0.2299
# ...         ...      ...    ...      ...
# 9014  Wholesale      KES  25.03    0.221
# 9051  Wholesale      KES  35.31   0.3118
# 9064  Wholesale      KES  33.43   0.2952
# 9160  Wholesale      KES  35.88   0.3112
# 9171  Wholesale      KES  37.88   0.3285
#
# [861 rows x 14 columns]

# %% [markdown]
# ## Converting csv to shp
