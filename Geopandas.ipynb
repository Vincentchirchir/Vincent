# %%
import numpy as np
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
county=gpd.read_file(r"C:\Users\VINCENT KIPRUTO\Documents\Kenya data\kenyadata\ke_subcounty.shp")

# %%
county
# Out:
#     country provpcode       province  ctypcode       county    scpcode  \
# 0     Kenya   KEN_1_1          Coast   KEN_2_1      Mombasa    KEN_3_6
# 1     Kenya   KEN_1_7         Nyanza  KEN_2_42       Kisumu  KEN_3_240
# 2     Kenya   KEN_1_3        Eastern  KEN_2_15        Kitui   KEN_3_70
# 3     Kenya   KEN_1_6        Western  KEN_2_39      Bungoma  KEN_3_219
# 4     Kenya   KEN_1_7         Nyanza  KEN_2_42       Kisumu  KEN_3_244
# ..      ...       ...            ...       ...          ...        ...
# 299   Kenya   KEN_1_3        Eastern  KEN_2_16     Machakos        NaN
# 300   Kenya   KEN_1_3        Eastern  KEN_2_16     Machakos   KEN_3_81
# 301   Kenya   KEN_1_2  North Eastern   KEN_2_9      Mandera        NaN
# 302   Kenya   KEN_1_2  North Eastern   KEN_2_9      Mandera   KEN_3_42
# 303   Kenya   KEN_1_5    Rift Valley  KEN_2_27  Uasin Gishu  KEN_3_144
#
#                      subcounty     dhis2_id  \
# 0            Mvita  Sub County  C1xuoa1NAMm
# ...

# %%
county.plot()
# Out:
# <AxesSubplot: >

# %%
county.head()
# Out:
#   country provpcode province  ctypcode   county    scpcode  \
# 0   Kenya   KEN_1_1    Coast   KEN_2_1  Mombasa    KEN_3_6
# 1   Kenya   KEN_1_7   Nyanza  KEN_2_42   Kisumu  KEN_3_240
# 2   Kenya   KEN_1_3  Eastern  KEN_2_15    Kitui   KEN_3_70
# 3   Kenya   KEN_1_6  Western  KEN_2_39  Bungoma  KEN_3_219
# 4   Kenya   KEN_1_7   Nyanza  KEN_2_42   Kisumu  KEN_3_244
#
#                    subcounty     dhis2_id  \
# 0          Mvita  Sub County  C1xuoa1NAMm
# 1  Kisumu Central Sub County  OpLt8IgyHop
# 2     Kitui West  Sub County  cmWAJB5kCDW
# 3          Bumula Sub County  jkQZEow83MX
# 4         Nyakach Sub County  kBQIjtWUBqj
#
#                                             geometry
# 0  POLYGON ((39.67760 -4.04654, 39.67773 -4.04659...
# 1  POLYGON ((34.76317 -0.12726, 34.76295 -0.12751...
# 2  POLYGON ((38.03021 -1.23441, 38.03012 -1.23849...
# 3  POLYGON ((34.52783 0.50833, 34.52831 0.50798, ...
# 4  POLYGON ((35.00564 -0.33966, 35.00569 -0.33964...

# %%
county.shape
# Out:
# (304, 9)

# %%
county.iloc[29]
# Out:
# country                                                  Kenya
# provpcode                                              KEN_1_5
# province                                           Rift Valley
# ctypcode                                              KEN_2_32
# county                                                  Nakuru
# scpcode                                              KEN_3_170
# subcounty                            Kuresoi South  Sub County
# dhis2_id                                           QwGkDS0DNls
# geometry     POLYGON ((35.71229322382732 -0.553894986394652...
# Name: 29, dtype: object

# %%
type(county)
# Out:
# geopandas.geodataframe.GeoDataFrame

# %%
county.isnull().sum()
# Out:
# country       0
# provpcode     0
# province      0
# ctypcode      0
# county        0
# scpcode      14
# subcounty     0
# dhis2_id      0
# geometry      0
# dtype: int64

# %%
county.geometry
# Out:
# 0      POLYGON ((39.67760 -4.04654, 39.67773 -4.04659...
# 1      POLYGON ((34.76317 -0.12726, 34.76295 -0.12751...
# 2      POLYGON ((38.03021 -1.23441, 38.03012 -1.23849...
# 3      POLYGON ((34.52783 0.50833, 34.52831 0.50798, ...
# 4      POLYGON ((35.00564 -0.33966, 35.00569 -0.33964...
#                              ...
# 299    POLYGON ((37.35751 -1.52616, 37.35753 -1.52645...
# 300    POLYGON ((37.14068 -1.56390, 37.14131 -1.55821...
# 301    POLYGON ((40.69359 2.77733, 40.69443 2.77617, ...
# 302    POLYGON ((41.02655 3.04799, 41.02692 3.04804, ...
# 303    POLYGON ((35.49577 0.32433, 35.49578 0.32427, ...
# Name: geometry, Length: 304, dtype: geometry

# %%
type(county.geometry)
# Out:
# geopandas.geoseries.GeoSeries

# %%
county.geometry.area
# Out:
# C:\Users\VINCENT KIPRUTO\AppData\Local\Temp\ipykernel_2204\930035882.py:1: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   county.geometry.area
# 0      0.001196
# 1      0.002645
# 2      0.054242
# 3      0.028103
# 4      0.028894
#          ...
# 299    0.050887
# 300    0.024300
# 301    0.200814
# 302    0.266486
# 303    0.038869
# Length: 304, dtype: float64

# %%
nakuru=county[county['county']=='Uasin Gishu']
nakuru
# Out:
#     country provpcode     province  ctypcode       county    scpcode  \
# 39    Kenya   KEN_1_5  Rift Valley  KEN_2_27  Uasin Gishu  KEN_3_143
# 82    Kenya   KEN_1_5  Rift Valley  KEN_2_27  Uasin Gishu  KEN_3_142
# 161   Kenya   KEN_1_5  Rift Valley  KEN_2_27  Uasin Gishu  KEN_3_146
# 191   Kenya   KEN_1_5  Rift Valley  KEN_2_27  Uasin Gishu  KEN_3_145
# 268   Kenya   KEN_1_5  Rift Valley  KEN_2_27  Uasin Gishu  KEN_3_141
# 303   Kenya   KEN_1_5  Rift Valley  KEN_2_27  Uasin Gishu  KEN_3_144
#
#                subcounty     dhis2_id  \
# 39     Moiben Sub County  q8R0FA1hxnP
# 82      Turbo Sub County  KuprsuBe1l0
# 161    Kesses Sub County  dKHnvt7gleN
# 191  Kapseret Sub County  u9yagZzK49q
# 268       Soy Sub County  lmr1q6dTaso
# 303  Ainabkoi Sub County  mYlMs4xTj82
#
#                                               geometry
# 39   MULTIPOLYGON (((35.27573 0.51279, 35.27573 0.5...
# 82   POLYGON ((35.00954 0.62831, 35.01104 0.62689, ...
# ...

# %%
nakuru.plot()
# Out:
# <AxesSubplot: >

# %%
nakuru.geometry.area
# Out:
# C:\Users\VINCENT KIPRUTO\AppData\Local\Temp\ipykernel_2204\2625921932.py:1: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   nakuru.geometry.area
# 39     0.064396
# 82     0.035141
# 161    0.051928
# 191    0.028839
# 268    0.051698
# 303    0.038869
# dtype: float64

# %%
county.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 299    False
# 300    False
# 301    False
# 302    False
# 303    False
# Length: 304, dtype: bool

# %%
 from shapely.geometry import Point, Polygon, LineString

# %%
p=Point(2,2)
p

# %%
poly=Polygon([(1,1),(2,2),(3,1)])
poly

# %%
line=LineString([(1,1), (2,2)])
line

# %%
county.geometry[29].area
# Out:
# 0.04637182441186654

# %% [markdown]
# ## Coordinate reference system

# %%
county.crs
# Out:
# <Geographic 2D CRS: EPSG:4326>
# Name: WGS 84
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - name: World.
# - bounds: (-180.0, -90.0, 180.0, 90.0)
# Datum: World Geodetic System 1984 ensemble
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %%
county_mercator=county.to_crs(epsg=3395)
county_mercator
# Out:
#     country provpcode       province  ctypcode       county    scpcode  \
# 0     Kenya   KEN_1_1          Coast   KEN_2_1      Mombasa    KEN_3_6
# 1     Kenya   KEN_1_7         Nyanza  KEN_2_42       Kisumu  KEN_3_240
# 2     Kenya   KEN_1_3        Eastern  KEN_2_15        Kitui   KEN_3_70
# 3     Kenya   KEN_1_6        Western  KEN_2_39      Bungoma  KEN_3_219
# 4     Kenya   KEN_1_7         Nyanza  KEN_2_42       Kisumu  KEN_3_244
# ..      ...       ...            ...       ...          ...        ...
# 299   Kenya   KEN_1_3        Eastern  KEN_2_16     Machakos       None
# 300   Kenya   KEN_1_3        Eastern  KEN_2_16     Machakos   KEN_3_81
# 301   Kenya   KEN_1_2  North Eastern   KEN_2_9      Mandera       None
# 302   Kenya   KEN_1_2  North Eastern   KEN_2_9      Mandera   KEN_3_42
# 303   Kenya   KEN_1_5    Rift Valley  KEN_2_27  Uasin Gishu  KEN_3_144
#
#                      subcounty     dhis2_id  \
# 0            Mvita  Sub County  C1xuoa1NAMm
# ...

# %%
county_mercator.plot()
# Out:
# <AxesSubplot: >

# %%
rivers=gpd.read_file(r"C:\Users\VINCENT KIPRUTO\Documents\Kenya data\kenyadata\KEN_Rivers\KEN_Rivers.shp")
rivers
# Out:
#             NAME                                           geometry
# 0           None  LINESTRING (33.98751 -0.44110, 33.99483 -0.445...
# 1           None  MULTILINESTRING ((34.00029 -0.49187, 33.99833 ...
# 2           None   LINESTRING (33.99978 0.00000, 34.00029 -0.00082)
# 3           None  LINESTRING (35.04110 -1.45793, 35.03493 -1.458...
# 4           None  LINESTRING (35.06113 -1.42845, 35.06045 -1.432...
# ...          ...                                                ...
# 13909  Akiriamet  LINESTRING (35.69373 1.34036, 35.69381 1.34119...
# 13910       None  LINESTRING (38.49868 -0.99149, 38.49365 -0.998...
# 13911       None    LINESTRING (35.75056 1.00854, 35.75663 1.00097)
# 13912       None    LINESTRING (35.71886 1.50110, 35.73176 1.48902)
# 13913       None  LINESTRING (37.49690 -2.97007, 37.50022 -2.96810)
#
# [13914 rows x 2 columns]

# %%
rivers.geometry
# Out:
# 0        LINESTRING (33.98751 -0.44110, 33.99483 -0.445...
# 1        MULTILINESTRING ((34.00029 -0.49187, 33.99833 ...
# 2         LINESTRING (33.99978 0.00000, 34.00029 -0.00082)
# 3        LINESTRING (35.04110 -1.45793, 35.03493 -1.458...
# 4        LINESTRING (35.06113 -1.42845, 35.06045 -1.432...
#                                ...
# 13909    LINESTRING (35.69373 1.34036, 35.69381 1.34119...
# 13910    LINESTRING (38.49868 -0.99149, 38.49365 -0.998...
# 13911      LINESTRING (35.75056 1.00854, 35.75663 1.00097)
# 13912      LINESTRING (35.71886 1.50110, 35.73176 1.48902)
# 13913    LINESTRING (37.49690 -2.97007, 37.50022 -2.96810)
# Name: geometry, Length: 13914, dtype: geometry

# %%
rivers.shape
# Out:
# (13914, 2)

# %%
rivers.plot()
# Out:
# <AxesSubplot: >

# %%
towns=gpd.read_file(r"C:\Users\VINCENT KIPRUTO\Documents\Kenya data\kenyadata\towns.shp")
towns
# Out:
#             TName                                 geometry
# 0          edwata  POINT Z (36.96590 -1.91909 94155.98943)
# 1       kaitorori  POINT Z (36.99332 -1.89706 90289.34237)
# 2        enkaroni  POINT Z (36.74086 -2.04415 95232.90283)
# 3             KMQ  POINT Z (36.69359 -1.92619 93045.42852)
# 4           TUALA  POINT Z (36.80861 -1.40528 96625.73617)
# ...           ...                                      ...
# 1243  mbwanjumale    POINT Z (41.13635 -2.08100 477.69189)
# 1244       KIPINI    POINT Z (40.52808 -2.52559 722.50619)
# 1245      NANIGHI   POINT Z (39.86986 -0.85821 6203.94594)
# 1246      mandani  POINT Z (39.64935 -3.83953 12118.94792)
# 1247      mulanjo   POINT Z (39.51632 -0.32167 8789.66164)
#
# [1248 rows x 2 columns]

# %%
towns.plot()
# Out:
# <AxesSubplot: >

# %% [markdown]
# ## Plotting different layers

# %%
ax = county.plot(edgecolor='k', facecolor='none', figsize=(15,10))
rivers.plot(ax=ax, color='blue')
towns.plot(ax=ax, color='red')
# Out:
# <AxesSubplot: >

# %%
import requests
import json

# %%
data=gpd.read_file(r"C:\Users\VINCENT KIPRUTO\Documents\WindowsPowerShell\Git_Hub\scipy2018-geospatial-data-master\data\cod_mines_curated_all_opendata_p_ipis.geojson")
data
# Out:
#                                                      id   vid  \
# 0     cod_mines_curated_all_opendata_p_ipis.fid-11f0...     1
# 1     cod_mines_curated_all_opendata_p_ipis.fid-11f0...     2
# 2     cod_mines_curated_all_opendata_p_ipis.fid-11f0...     3
# 3     cod_mines_curated_all_opendata_p_ipis.fid-11f0...     4
# 4     cod_mines_curated_all_opendata_p_ipis.fid-11f0...     5
# ...                                                 ...   ...
# 3682  cod_mines_curated_all_opendata_p_ipis.fid-11f0...  3683
# 3683  cod_mines_curated_all_opendata_p_ipis.fid-11f0...  3684
# 3684  cod_mines_curated_all_opendata_p_ipis.fid-11f0...  3685
# 3685  cod_mines_curated_all_opendata_p_ipis.fid-11f0...  3686
# 3686  cod_mines_curated_all_opendata_p_ipis.fid-11f0...  3687
#
#                           source               project         pcode  \
# 0     IPIS - Ministère des Mines           IPIS - 2009  codmine00191
# 1     IPIS - Ministère des Mines           IPIS - 2009  codmine00192
# ...

# %%
data.shape
# Out:
# (3687, 62)

# %% [markdown]
# # Select columns that we need

# %%
#We have so many columns i.e 62, we select only what we need
data=data[['vid', 'project', 'visit_date', 'name', 'pcode', 'workers_numb', 'interference', 'armed_group1', 'mineral1']]
data
# Out:
#        vid               project  visit_date                  name  \
# 0        1           IPIS - 2009  2009-01-01                  Eohe
# 1        2           IPIS - 2009  2009-01-01                  Eita
# 2        3           IPIS - 2009  2009-01-01             Mungu Iko
# 3        4           IPIS - 2009  2009-01-01          Kiviri/Tayna
# 4        5           IPIS - 2009  2009-01-01               Makanga
# ...    ...                   ...         ...                   ...
# 3682  3683  IPIS - IOM 2016-2018  2017-12-24  Kitumba /nyamitulano
# 3683  3684  IPIS - IOM 2016-2018  2017-12-26                Apemba
# 3684  3685  IPIS - IOM 2016-2018  2017-12-27                Kisasa
# 3685  3686  IPIS - IOM 2016-2018  2017-12-27           Kindikimozi
# 3686  3687  IPIS - IOM 2016-2018  2017-12-27                Ngombi
#
#              pcode  workers_numb  interference    armed_group1     mineral1
# 0     codmine00191         300.0           NaN            None           Or
# ...

# %%
data.isnull().sum()
# Out:
# vid                0
# project            0
# visit_date         0
# name               0
# pcode              0
# workers_numb     658
# interference     709
# armed_group1    2334
# mineral1          10
# dtype: int64

# %%
#Take only data of visits by IPIS
data_ipis=data[data['project'].str.contains('IPIS') & (data['workers_numb']>0)]
data_ipis
# Out:
#        vid               project  visit_date                  name  \
# 0        1           IPIS - 2009  2009-01-01                  Eohe
# 1        2           IPIS - 2009  2009-01-01                  Eita
# 5        6           IPIS - 2009  2009-01-01            Maliyajama
# 6        7           IPIS - 2009  2009-01-01               Mununze
# 7        8           IPIS - 2009  2009-01-01                Kiboto
# ...    ...                   ...         ...                   ...
# 3682  3683  IPIS - IOM 2016-2018  2017-12-24  Kitumba /nyamitulano
# 3683  3684  IPIS - IOM 2016-2018  2017-12-26                Apemba
# 3684  3685  IPIS - IOM 2016-2018  2017-12-27                Kisasa
# 3685  3686  IPIS - IOM 2016-2018  2017-12-27           Kindikimozi
# 3686  3687  IPIS - IOM 2016-2018  2017-12-27                Ngombi
#
#              pcode  workers_numb  interference    armed_group1     mineral1
# 0     codmine00191         300.0           NaN            None           Or
# ...

# %%
# For those mines sites that were visited multiple times, take only the last visits

# %% [markdown]
# # Spatial relationship and operation

# %%
countries=gpd.read_file(r"C:\Users\VINCENT KIPRUTO\Documents\WindowsPowerShell\Git_Hub\scipy2018-geospatial-data-master\data\Countries\ne_110m_admin_0_countries.shp")
cities=gpd.read_file(r"C:\Users\VINCENT KIPRUTO\Documents\WindowsPowerShell\Git_Hub\scipy2018-geospatial-data-master\data\Cities\ne_110m_populated_places.shp")
rivers=gpd.read_file(r"C:\Users\VINCENT KIPRUTO\Documents\WindowsPowerShell\Git_Hub\scipy2018-geospatial-data-master\data\Rivers\ne_50m_rivers_lake_centerlines.shp")

# %%
countries
# Out:
#     iso_a3                  name      continent     pop_est  gdp_md_est  \
# 0      AFG           Afghanistan           Asia  34124811.0     64080.0
# 1      AGO                Angola         Africa  29310273.0    189000.0
# 2      ALB               Albania         Europe   3047987.0     33900.0
# 3      ARE  United Arab Emirates           Asia   6072475.0    667200.0
# 4      ARG             Argentina  South America  44293293.0    879400.0
# ..     ...                   ...            ...         ...         ...
# 172    VUT               Vanuatu        Oceania    282814.0       723.0
# 173    YEM                 Yemen           Asia  28036829.0     73450.0
# 174    ZAF          South Africa         Africa  54841552.0    739100.0
# 175    ZMB                Zambia         Africa  15972000.0     65170.0
# 176    ZWE              Zimbabwe         Africa  13805084.0     28330.0
#
#                                               geometry
# ...

# %%
kenya=countries.loc[countries['name']=='Kenya','geometry'].squeeze()
kenya

# %%
nairobi=cities.loc[cities['name']=='Nairobi', 'geometry'].squeeze()
nairobi

# %%
kampala=cities.loc[cities['name']=='Kampala', 'geometry'].squeeze()
kampala

# %%
#Add line string between two cities
line=LineString([nairobi, kampala])
line

# %%
#Let us visualize the 4 together
gpd.GeoSeries([kenya, nairobi, kampala, line]).plot(cmap='tab10')
# Out:
# <AxesSubplot: >

# %%
france=countries.loc[countries['name']=='France', 'geometry'].squeeze()
france

# %%
spain=countries.loc[countries['name']=='Spain', 'geometry'].squeeze()
spain

# %%
paris=cities.loc[cities['name']=='Paris', 'geometry'].squeeze()
paris

# %%
madrid=cities.loc[cities['name']=='Madrid', 'geometry'].squeeze()
madrid

# %%
line=LineString([paris, madrid])
line

# %%
gpd.GeoSeries([france, spain, paris, madrid,line]).plot(cmap='tab10')
# Out:
# <AxesSubplot: >

# %%
nairobi.within(kenya)
# Out:
# True

# %%
kenya.contains(nairobi)
# Out:
# True

# %% [markdown]
# ## Spatial relationships with GeoDataFrame

# %%
countries.contains(nairobi).sum()
# Out:
# 1

# %%
countries[countries.contains(nairobi)]
# Out:
#    iso_a3   name continent     pop_est  gdp_md_est  \
# 84    KEN  Kenya    Africa  47615739.0    152700.0
#
#                                              geometry
# 84  POLYGON ((35.29801 5.50600, 35.81745 5.33823, ...

# %%
rivers
# Out:
#      scalerank       featurecla      name          note  min_zoom name_alt  \
# 0            6  Lake Centerline      Kama          None       5.0     None
# 1            6            River      Kama          None       5.0     None
# 2            3  Lake Centerline      Abay          None       3.0     None
# 3            3  Lake Centerline  Al Furat          None       3.0     None
# 4            6  Lake Centerline   Alabama          None       5.0     None
# ..         ...              ...       ...           ...       ...      ...
# 457          5            River      None  _untitled_79       4.7     None
# 458          5  Lake Centerline      None  _untitled_78       4.7     None
# 459          6            River   Garonne          None       5.0     None
# 460          5            River     Loire          None       4.7     None
# 461          5            River     Loire  Fixed in 4.0       4.7     None
#
# ...

# %%
rivers.query('name=="Nile"')
# Out:
#      scalerank       featurecla  name  note  min_zoom name_alt name_en  \
# 47           1  Lake Centerline  Nile  None       2.0     None    Nile
# 298          1            River  Nile  None       2.0     None    Nile
#
#      min_label                                           geometry
# 47         3.0  LINESTRING (32.87947 23.98768, 32.90872 23.808...
# 298        3.0  MULTILINESTRING ((32.49014 15.63455, 32.53541 ...

# %%
nile=rivers[rivers['name']=='Nile'].geometry.squeeze()
nile
# Out:
# 47     LINESTRING (32.87947 23.98768, 32.90872 23.808...
# 298    MULTILINESTRING ((32.49014 15.63455, 32.53541 ...
# Name: geometry, dtype: geometry

# %%
nile
# Out:
# 47     LINESTRING (32.87947 23.98768, 32.90872 23.808...
# 298    MULTILINESTRING ((32.49014 15.63455, 32.53541 ...
# Name: geometry, dtype: geometry

# %%
countries[countries.intersects(nile)] #crosses
# Out:
# C:\Users\VINCENT KIPRUTO\.conda\envs\geo_env\Lib\site-packages\geopandas\base.py:31: UserWarning: The indices of the two GeoSeries are different.
#   warn("The indices of the two GeoSeries are different.")
# C:\Users\VINCENT KIPRUTO\.conda\envs\geo_env\Lib\site-packages\geopandas\geodataframe.py:1415: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   result = super().__getitem__(key)
#    iso_a3   name continent     pop_est  gdp_md_est  \
# 47    EGY  Egypt    Africa  97041072.0   1105000.0
#
#                                              geometry
# 47  POLYGON ((36.86623 22.00000, 32.90000 22.00000...

# %%
amazon=rivers[rivers['name']=='Amazonas'].geometry.squeeze()

# %%
amazon

# %%
countries[countries.crosses(amazon)]
# Out:
#     iso_a3      name      continent      pop_est  gdp_md_est  \
# 22     BRA    Brazil  South America  207353391.0   3081000.0
# 35     COL  Colombia  South America   47698524.0    688000.0
# 124    PER      Peru  South America   31036656.0    410400.0
#
#                                               geometry
# 22   POLYGON ((-57.62513 -30.21629, -56.29090 -28.8...
# 35   POLYGON ((-66.87633 1.25336, -67.06505 1.13011...
# 124  POLYGON ((-69.52968 -10.95173, -68.66508 -12.5...

# %%
kenya=countries.loc[countries['name']=='Kenya', 'geometry'].squeeze()
kenya

# %%
countries[countries.touches(kenya)]
# Out:
#     iso_a3      name continent      pop_est  gdp_md_est  \
# 51     ETH  Ethiopia    Africa  105350020.0    174700.0
# 140    SDS  S. Sudan    Africa   13026129.0     20880.0
# 146    SOM   Somalia    Africa    7531386.0      4719.0
# 164    TZA  Tanzania    Africa   53950935.0    150600.0
# 165    UGA    Uganda    Africa   39570125.0     84930.0
#
#                                               geometry
# 51   POLYGON ((42.35156 12.54223, 42.00000 12.10000...
# 140  POLYGON ((27.37423 5.23394, 27.21341 5.55095, ...
# 146  POLYGON ((41.85508 3.91891, 42.12861 4.23413, ...
# 164  POLYGON ((29.34000 -4.49998, 29.75351 -4.45239...
# 165  POLYGON ((29.57947 -1.34131, 29.58784 -0.58741...

# %% [markdown]
# ## Spatial operation

# %%
#Buffer
gpd.GeoSeries([nairobi.buffer(1), nairobi]).plot(alpha=0.5, cmap='tab10')
# Out:
# <AxesSubplot: >

# %%
#intersection
nairobi.buffer(1).intersection(kenya)

# %%
#constructing a single object from different countries eg Africa from African countries
African_countries=countries[countries['continent']=='Africa']
africa=African_countries.unary_union
africa

# %%
#create a single polygon for Europe
Europe_countries=countries[countries['continent']=='Europe']
Europe=Europe_countries.unary_union
Europe

# %%
#Create a single polygon with all of the countries that you have to cross to travel from beijing to sydney
beijing=cities.loc[cities['name']=='Beijing', 'geometry'].squeeze()
beijing

# %%
china=countries.loc[countries['name']=='China', 'geometry'].squeeze()
china

# %%
gpd.GeoSeries([china, beijing]).plot(cmap='tab10')
# Out:
# <AxesSubplot: >

# %%
australia=countries.loc[countries['name']=='Australia', 'geometry'].squeeze()
australia

# %%
sydney=cities.loc[cities['name']=='Sydney', 'geometry'].squeeze()
sydney

# %%
gpd.GeoSeries([australia, sydney]).plot(cmap='tab10')
# Out:
# <AxesSubplot: >

# %%
line=LineString([sydney, beijing])
line

# %%
gpd.GeoSeries([china, beijing, australia, sydney, line]).plot(cmap='tab10')
# Out:
# <AxesSubplot: >

# %%
poly=countries[countries.crosses(line)]
poly
# Out:
#    iso_a3       name continent       pop_est  gdp_md_est  \
# 8     AUS  Australia   Oceania  2.323241e+07   1189000.0
# 30    CHN      China      Asia  1.379303e+09  21140000.0
# 72    IDN  Indonesia      Asia  2.605807e+08   3028000.0
#
#                                              geometry
# 8   MULTIPOLYGON (((145.39798 -40.79255, 146.36412...
# 30  MULTIPOLYGON (((75.15803 37.13303, 74.98000 37...
# 72  MULTIPOLYGON (((120.71561 -10.23958, 120.29501...

# %%
single_polygon=poly[poly['continent']=='Asia']
single_poly=single_polygon.unary_union
single_poly

# %% [markdown]
# ## Spatial Joins
# With spatial joins you can determine for each city the country in which it is located
# You achieve this by combining information of geospatial datasets based on their spatial relationship

# %%
#To illustrate the concept of joining the information of two dataframes with pandas, I will take a small subset of cities and countries datasets
cities2=cities[cities['name'].isin(['Bern', 'London', 'Brussels', 'Paris'])].copy()
cities2['iso_a3']=['CHE','BEL', 'GBR', 'FRA']
cities2
# Out:
#          name                   geometry iso_a3
# 26       Bern   POINT (7.46698 46.91668)    CHE
# 170  Brussels   POINT (4.33137 50.83526)    BEL
# 219    London  POINT (-0.11867 51.50194)    GBR
# 235     Paris   POINT (2.33139 48.86864)    FRA

# %%
countries2=countries[['iso_a3', 'name', 'continent']]
countries2.head()
# Out:
#   iso_a3                  name      continent
# 0    AFG           Afghanistan           Asia
# 1    AGO                Angola         Africa
# 2    ALB               Albania         Europe
# 3    ARE  United Arab Emirates           Asia
# 4    ARG             Argentina  South America

# %%
cities2.merge(countries2, on='iso_a3')
# Out:
#      name_x                   geometry iso_a3          name_y continent
# 0      Bern   POINT (7.46698 46.91668)    CHE     Switzerland    Europe
# 1  Brussels   POINT (4.33137 50.83526)    BEL         Belgium    Europe
# 2    London  POINT (-0.11867 51.50194)    GBR  United Kingdom    Europe
# 3     Paris   POINT (2.33139 48.86864)    FRA          France    Europe

# %% [markdown]
# # Spatila Join

# %%
join=gpd.sjoin(cities, countries, op='within', how='left')
join
# Out:
# C:\Users\VINCENT KIPRUTO\.conda\envs\geo_env\Lib\site-packages\IPython\core\interactiveshell.py:3373: FutureWarning: The `op` parameter is deprecated and will be removed in a future release. Please use the `predicate` parameter instead.
#   if await self.run_code(code, result, async_=asy):
#           name_left                     geometry  index_right iso_a3  \
# 0      Vatican City    POINT (12.45339 41.90328)         79.0    ITA
# 1        San Marino    POINT (12.44177 43.93610)         79.0    ITA
# 2             Vaduz     POINT (9.51667 47.13372)          9.0    AUT
# 3           Lobamba   POINT (31.20000 -26.46667)        152.0    SWZ
# 4        Luxembourg     POINT (6.13000 49.61166)         97.0    LUX
# ..              ...                          ...          ...    ...
# 238  Rio de Janeiro  POINT (-43.22697 -22.92308)         22.0    BRA
# 239       São Paulo  POINT (-46.62697 -23.55673)         22.0    BRA
# ...

# %%
#Create a single polygon with all of the counties that you have to cross to travel from kisumu to nairobi
county.head()
# Out:
#   country provpcode province  ctypcode   county    scpcode  \
# 0   Kenya   KEN_1_1    Coast   KEN_2_1  Mombasa    KEN_3_6
# 1   Kenya   KEN_1_7   Nyanza  KEN_2_42   Kisumu  KEN_3_240
# 2   Kenya   KEN_1_3  Eastern  KEN_2_15    Kitui   KEN_3_70
# 3   Kenya   KEN_1_6  Western  KEN_2_39  Bungoma  KEN_3_219
# 4   Kenya   KEN_1_7   Nyanza  KEN_2_42   Kisumu  KEN_3_244
#
#                    subcounty     dhis2_id  \
# 0          Mvita  Sub County  C1xuoa1NAMm
# 1  Kisumu Central Sub County  OpLt8IgyHop
# 2     Kitui West  Sub County  cmWAJB5kCDW
# 3          Bumula Sub County  jkQZEow83MX
# 4         Nyakach Sub County  kBQIjtWUBqj
#
#                                             geometry
# 0  POLYGON ((39.67760 -4.04654, 39.67773 -4.04659...
# 1  POLYGON ((34.76317 -0.12726, 34.76295 -0.12751...
# 2  POLYGON ((38.03021 -1.23441, 38.03012 -1.23849...
# 3  POLYGON ((34.52783 0.50833, 34.52831 0.50798, ...
# 4  POLYGON ((35.00564 -0.33966, 35.00569 -0.33964...

# %%
kisumu=county.loc[county['county']=='Kisumu', 'geometry'].squeeze()
kisumu
# Out:
# 1      POLYGON ((34.76317 -0.12726, 34.76295 -0.12751...
# 4      POLYGON ((35.00564 -0.33966, 35.00569 -0.33964...
# 189    POLYGON ((35.22701 -0.10920, 35.22942 -0.11242...
# 203    POLYGON ((34.81500 -0.07033, 34.81589 -0.07041...
# 215    MULTIPOLYGON (((34.47028 -0.18036, 34.47025 -0...
# 228    POLYGON ((34.90780 -0.17155, 34.90791 -0.17142...
# 232    MULTIPOLYGON (((34.60832 -0.16084, 34.60895 -0...
# Name: geometry, dtype: geometry

# %%
towns=gpd.read_file(r"C:\Users\VINCENT KIPRUTO\Documents\Kenya data\kenyadata\towns.shp")
towns.head()
# Out:
#        TName                                 geometry
# 0     edwata  POINT Z (36.96590 -1.91909 94155.98943)
# 1  kaitorori  POINT Z (36.99332 -1.89706 90289.34237)
# 2   enkaroni  POINT Z (36.74086 -2.04415 95232.90283)
# 3        KMQ  POINT Z (36.69359 -1.92619 93045.42852)
# 4      TUALA  POINT Z (36.80861 -1.40528 96625.73617)

# %%
towns.iloc[]
# Out:
# TName                                                  edwata
# geometry    POINT Z (36.96589848262537 -1.9190907140540572...
# Name: 0, dtype: object

# %%
kisumu_town=towns.loc[towns['TName']=='KISUMU', 'geometry'].squeeze()
kisumu_town
# Out:
# GeoSeries([], Name: geometry, dtype: geometry)

# %%
towns.shape
# Out:
# (1248, 2)

# %%
join=gpd.sjoin(towns, county, op='within', how='left')
join
# Out:
# C:\Users\VINCENT KIPRUTO\.conda\envs\geo_env\Lib\site-packages\IPython\core\interactiveshell.py:3373: FutureWarning: The `op` parameter is deprecated and will be removed in a future release. Please use the `predicate` parameter instead.
#   if await self.run_code(code, result, async_=asy):
#             TName                                 geometry  index_right  \
# 0          edwata  POINT Z (36.96590 -1.91909 94155.98943)        173.0
# 1       kaitorori  POINT Z (36.99332 -1.89706 90289.34237)        173.0
# 2        enkaroni  POINT Z (36.74086 -2.04415 95232.90283)        173.0
# 3             KMQ  POINT Z (36.69359 -1.92619 93045.42852)        254.0
# 4           TUALA  POINT Z (36.80861 -1.40528 96625.73617)        143.0
# ...           ...                                      ...          ...
# 1243  mbwanjumale    POINT Z (41.13635 -2.08100 477.69189)        239.0
# 1244       KIPINI    POINT Z (40.52808 -2.52559 722.50619)        212.0
# ...

# %%
join.iloc[500]
# Out:
# TName                                                     NDOVEA
# geometry       POINT Z (37.55764652023759 -1.9617939527486954...
# index_right                                                  6.0
# country                                                    Kenya
# provpcode                                                KEN_1_3
# province                                                 Eastern
# ctypcode                                                KEN_2_17
# county                                                   Makueni
# scpcode                                                 KEN_3_86
# subcounty                                    Makueni  Sub County
# dhis2_id                                             AIGIQpolMRn
# Name: 500, dtype: object

# %%
towns.crs
# Out:
# <Geographic 2D CRS: EPSG:4326>
# Name: WGS 84
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - name: World.
# - bounds: (-180.0, -90.0, 180.0, 90.0)
# Datum: World Geodetic System 1984 ensemble
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %%
edwata=towns.loc[towns['TName']=='edwata', 'geometry'].squeeze()
edwata

# %%
kajiado=county.loc[county['county']=='Kajiado', 'geometry'].squeeze()
kajiado
# Out:
# 78     POLYGON ((37.87581 -3.04208, 37.87142 -3.07911...
# 143    POLYGON ((37.37156 -2.01885, 37.37434 -2.02025...
# 173    POLYGON ((37.04808 -2.36993, 37.04090 -2.38573...
# 254    POLYGON ((36.70564 -1.91952, 36.70676 -1.92017...
# 263    POLYGON ((36.71871 -1.36716, 36.71879 -1.36724...
# Name: geometry, dtype: geometry

# %%
county.crs
# Out:
# <Geographic 2D CRS: EPSG:4326>
# Name: WGS 84
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - name: World.
# - bounds: (-180.0, -90.0, 180.0, 90.0)
# Datum: World Geodetic System 1984 ensemble
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %%
gpd.GeoSeries([kajiado, edwata]).plot(cmap='tab10')
# Out:
# C:\Users\VINCENT KIPRUTO\.conda\envs\geo_env\Lib\site-packages\shapely\geometry\geo.py:123: ShapelyDeprecationWarning: GeometryTypeError will derive from ShapelyError and not TypeError or ValueError in Shapely 2.0.
#   raise GeometryTypeError("Unknown geometry type: %s" % geom_type)
# ---------------------------------------------------------------------------
# GeometryTypeError                         Traceback (most recent call last)
# File ~\.conda\envs\geo_env\Lib\site-packages\geopandas\geoseries.py:221, in GeoSeries.__init__(self, data, index, crs, **kwargs)
#     220 try:
# --> 221     data = from_shapely(s.values, crs)
#     222 except TypeError:
#
# File ~\.conda\envs\geo_env\Lib\site-packages\geopandas\array.py:154, in from_shapely(data, crs)
#     139 """
#     140 Convert a list or array of shapely objects to a GeometryArray.
#     141
#    (...)
#     152
#     153 """
# --> 154 return GeometryArray(vectorized.from_shapely(data), crs=crs)
#
# ...

# %%
nairobi=towns.loc[towns['TName']=='NRB', 'geometry'].squeeze()
nairobi
# Out:
# GeoSeries([], Name: geometry, dtype: geometry)

# %% [markdown]
# # Keiyo South

# %%
keiyo=county[county['subcounty']=='Keiyo South Sub County']
keiyo
# Out:
#     country provpcode     province  ctypcode           county    scpcode  \
# 125   Kenya   KEN_1_5  Rift Valley  KEN_2_28  Elgeyo-Marakwet  KEN_3_150
#
#                   subcounty     dhis2_id  \
# 125  Keiyo South Sub County  SOEG546PqbA
#
#                                               geometry
# 125  POLYGON ((35.69520 0.18752, 35.69516 0.18746, ...

# %%
county.plot(facecolor='none')
# Out:
# <AxesSubplot: >

# %%
keiyo.plot(facecolor='none')
# Out:
# <AxesSubplot: >

# %% [markdown]
# # Villages

# %%
villages=gpd.read_file(r"C:\Users\VINCENT KIPRUTO\Documents\Kenya data\kenyadata\villages.shp")
villages
# Out:
#                VName                   geometry
# 0            ABABULE   POINT (39.78000 0.95000)
# 1           ABACHULA  POINT (39.53000 -0.60000)
# 2          ABADARANT   POINT (40.53000 1.53000)
# 3      ABAFAYO MELKA   POINT (38.97000 1.20000)
# 4         ABAGERANSO   POINT (40.32000 1.75000)
# ...              ...                        ...
# 28810        OGORCHI   POINT (39.45000 3.22000)
# 28811        OGORCHI   POINT (39.45000 3.22000)
# 28812        OGORCHI   POINT (39.45000 3.22000)
# 28813          SIAYA   POINT (34.28000 0.05000)
# 28814           SEGA   POINT (34.22000 0.25000)
#
# [28815 rows x 2 columns]

# %%
villages.shape
# Out:
# (28815, 2)

# %%
villages.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 28815 entries, 0 to 28814
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   VName     28815 non-null  object
#  1   geometry  28815 non-null  geometry
# dtypes: geometry(1), object(1)
# memory usage: 450.4+ KB

# %%
villages.isnull().sum()
# Out:
# VName       0
# geometry    0
# dtype: int64

# %%
villages.plot()
# Out:
# <AxesSubplot: >

# %%
villages.head()
# Out:
#            VName                   geometry
# 0        ABABULE   POINT (39.78000 0.95000)
# 1       ABACHULA  POINT (39.53000 -0.60000)
# 2      ABADARANT   POINT (40.53000 1.53000)
# 3  ABAFAYO MELKA   POINT (38.97000 1.20000)
# 4     ABAGERANSO   POINT (40.32000 1.75000)

# %%
villages[villages['VName']=='KAPKITONY']
# Out:
#           VName                  geometry
# 8790  KAPKITONY  POINT (36.15000 0.18000)

# %%
villages.count()
# Out:
# VName       28815
# geometry    28815
# dtype: int64

# %%
villages['VName'].value_counts()
# Out:
# ENCHORRO                  20
# LUANDA                    19
# KIBOKO                    18
# AMAN                      18
# AWACH                     15
#                           ..
# KIKIKUMWASUBSURFACEDAM     1
# KIKIMA                     1
# KIKIMADAM                  1
# KIKINGOFOREST              1
# LEGOMAN                    1
# Name: VName, Length: 19406, dtype: int64

# %%
villages.isnull().sum()
# Out:
# VName       0
# geometry    0
# dtype: int64

# %%
villages.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 28810    False
# 28811     True
# 28812     True
# 28813    False
# 28814     True
# Length: 28815, dtype: bool

# %%
dup=villages.duplicated().sum()
dup
# Out:
# 6396

# %%
villages.describe()
# Out:
# C:\Users\VINCENT KIPRUTO\.conda\envs\geo_env\Lib\site-packages\pandas\core\dtypes\cast.py:127: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
#            VName                                       geometry
# count      28815                                          28815
# unique     19406                                          16898
# top     ENCHORRO  POINT (37.29999923706055 -0.1500000059604645)
# freq          20                                             26

# %%
villages['VName'].unique()
# Out:
# array(['ABABULE', 'ABACHULA', 'ABADARANT', ..., 'ZUTIROAD',
#        'CENTRALKAVIRONDODISTRICT', 'MIRIHINI'], dtype=object)

# %%
villages.plot(figsize=(12,6))
# Out:
# <AxesSubplot: >
